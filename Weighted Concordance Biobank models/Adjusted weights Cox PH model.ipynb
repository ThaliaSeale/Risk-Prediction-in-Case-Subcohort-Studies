# %% [markdown]
# # Barlow Cox PH model

# %%
import numpy as np
import pandas as pd
from datetime import datetime

import pickle

from weighted_concordance import *

# %%
# pd.set_option('display.max_columns', None,'display.max_rows',20)

# %%
from lifelines import CoxPHFitter
from lifelines.utils import datetimes_to_durations

# %%
# importing data
X_tr = pd.read_csv("D:/compiled_data/X_tr.csv").set_index("csid")

y = pd.read_csv("D:/compiled_data/y.csv").set_index("csid")

# %% [markdown]
# Converting date-times from string format to datetime format.

# %%
def date_time_conversion(date):
    return(datetime.strptime(date,"%Y-%m-%dT%H:%M:%SZ"))

# %%
# Coverting the times into datetime format
y_tr = y.assign(
    event = y.ep_CKB0020_combined_ep,
    start_time = y.study_date.map(date_time_conversion),
    event_time = y.ep_CKB0020_combined_datedeveloped.map(date_time_conversion)
).drop(columns = y.columns)
y_tr["duration"] = datetimes_to_durations(y_tr["start_time"],y_tr["event_time"])[0]
y_tr["subcohort"] = y["subcohort"]
y_tr = y_tr.drop(columns = ["start_time","event_time"])

# %% [markdown]
# ## Fitting Model

# %% [markdown]
# The procedure is the same as making a Barlow data set, it's just that we adjust the size of the weighting of the subcohort. We still need to reduce dimension through PCA.

# %% [markdown]
# See "Unweighted Cox PH with PCA" file for more detailed code annotation.

# %%
from sklearn.decomposition import PCA
from lifelines.utils import k_fold_cross_validation, concordance_index
from sklearn.model_selection import KFold

# %%
cox_adjusted_pca_scores =  pd.DataFrame({
    'PCA' : [],
    'Weight': [],
    'score': []
})
cox_adjusted_pca_scores
# Out:
# Empty DataFrame
# Columns: [PCA, Weight, score]
# Index: []

# %%
# sampling proportion of cohort
alpha = len(y_tr.query("subcohort == True"))/1400

for i in range(1,15):
    for j in range(1,round(1/alpha)*8):
        
        print("Prop. variance:", i/20 , "Weight:", j/4)
    
        kf = KFold(n_splits=3)
        kf.get_n_splits(X_tr)

        scores = []

        for train_index, test_index in kf.split(X_tr):
            X_tr_train, X_tr_test = X_tr.iloc[train_index], X_tr.iloc[test_index]
            y_tr_train, y_tr_test = y_tr.iloc[train_index], y_tr.iloc[test_index]

            pca = PCA(n_components = i/20)
            X_tr_train_pca = pd.DataFrame(pca.fit_transform(X_tr_train))
            X_tr_train_pca.index = X_tr_train.index

            # creating a case dataframe
            cases_barlow_df = X_tr_train_pca.join(y_tr_train).query("subcohort == False")

            cases_barlow_df = cases_barlow_df.assign(
                # setting events outside subcohort to start just before they occur
                start_time = lambda df: df["duration"] - 0.001,
                # adding appropriate weight
                weight = 1,
                subcohort = False
            )

            # creating a subcohort dataframe
            subcohort_barlow_df = X_tr_train_pca.join(y_tr_train).query("subcohort == True")

            subcohort_barlow_df = subcohort_barlow_df.assign(
                    # if it is a case, the weight should be the same as the subcohort until close to the time of the event. 
                    duration = lambda df: np.where(df["event"], df["duration"] - 0.001, df["duration"]), 
                    # the events start from the origin
                    start_time = 0, 
                    event = False,
                    weight = j/4,
                    subcohort = True
                )

            case_subcohort_barlow_df = pd.concat([cases_barlow_df,subcohort_barlow_df]).drop(columns = "subcohort")

            cph = CoxPHFitter()
            cph.fit(case_subcohort_barlow_df, entry_col = "start_time", duration_col = "duration",event_col = "event",weights_col = "weight",robust = True)

            event_times = y_tr_test["duration"]
            event_observed = y_tr_test["event"]
            
            X_tr_pca_test = pca.transform(X_tr_test)

            test_preds = cph.predict_partial_hazard(X_tr_pca_test)
            scores.append(weighted_concordance(event_times,test_preds, event_observed,0.0011604684001529089))

        cox_adjusted_pca_scores = cox_adjusted_pca_scores.append({
            'PCA' : i/20,
            'Weight': j/4,
            'score': np.mean(scores)
        }, ignore_index = True)
# Out:
# Prop. variance: 0.05 Weight: 0.25
# Prop. variance: 0.05 Weight: 0.5
# Prop. variance: 0.05 Weight: 0.75
# Prop. variance: 0.05 Weight: 1.0
# Prop. variance: 0.05 Weight: 1.25
# Prop. variance: 0.05 Weight: 1.5
# Prop. variance: 0.05 Weight: 1.75
# Prop. variance: 0.05 Weight: 2.0
# Prop. variance: 0.05 Weight: 2.25
# Prop. variance: 0.05 Weight: 2.5
# Prop. variance: 0.05 Weight: 2.75
# Prop. variance: 0.05 Weight: 3.0
# Prop. variance: 0.05 Weight: 3.25
# Prop. variance: 0.05 Weight: 3.5
# Prop. variance: 0.05 Weight: 3.75
# Prop. variance: 0.1 Weight: 0.25
# Prop. variance: 0.1 Weight: 0.5
# Prop. variance: 0.1 Weight: 0.75
# Prop. variance: 0.1 Weight: 1.0
# Prop. variance: 0.1 Weight: 1.25
# Prop. variance: 0.1 Weight: 1.5
# Prop. variance: 0.1 Weight: 1.75
# Prop. variance: 0.1 Weight: 2.0
# Prop. variance: 0.1 Weight: 2.25
# Prop. variance: 0.1 Weight: 2.5
# Prop. variance: 0.1 Weight: 2.75
# Prop. variance: 0.1 Weight: 3.0
# Prop. variance: 0.1 Weight: 3.25
# Prop. variance: 0.1 Weight: 3.5
# Prop. variance: 0.1 Weight: 3.75
# Prop. variance: 0.15 Weight: 0.25
# Prop. variance: 0.15 Weight: 0.5
# Prop. variance: 0.15 Weight: 0.75
# Prop. variance: 0.15 Weight: 1.0
# Prop. variance: 0.15 Weight: 1.25
# Prop. variance: 0.15 Weight: 1.5
# Prop. variance: 0.15 Weight: 1.75
# Prop. variance: 0.15 Weight: 2.0
# Prop. variance: 0.15 Weight: 2.25
# Prop. variance: 0.15 Weight: 2.5
# Prop. variance: 0.15 Weight: 2.75
# Prop. variance: 0.15 Weight: 3.0
# Prop. variance: 0.15 Weight: 3.25
# Prop. variance: 0.15 Weight: 3.5
# Prop. variance: 0.15 Weight: 3.75
# Prop. variance: 0.2 Weight: 0.25
# Prop. variance: 0.2 Weight: 0.5
# Prop. variance: 0.2 Weight: 0.75
# Prop. variance: 0.2 Weight: 1.0
# Prop. variance: 0.2 Weight: 1.25
# Prop. variance: 0.2 Weight: 1.5
# Prop. variance: 0.2 Weight: 1.75
# Prop. variance: 0.2 Weight: 2.0
# Prop. variance: 0.2 Weight: 2.25
# Prop. variance: 0.2 Weight: 2.5
# Prop. variance: 0.2 Weight: 2.75
# Prop. variance: 0.2 Weight: 3.0
# Prop. variance: 0.2 Weight: 3.25
# Prop. variance: 0.2 Weight: 3.5
# Prop. variance: 0.2 Weight: 3.75
# Prop. variance: 0.25 Weight: 0.25
# Prop. variance: 0.25 Weight: 0.5
# Prop. variance: 0.25 Weight: 0.75
# Prop. variance: 0.25 Weight: 1.0
# Prop. variance: 0.25 Weight: 1.25
# Prop. variance: 0.25 Weight: 1.5
# Prop. variance: 0.25 Weight: 1.75
# Prop. variance: 0.25 Weight: 2.0
# Prop. variance: 0.25 Weight: 2.25
# Prop. variance: 0.25 Weight: 2.5
# Prop. variance: 0.25 Weight: 2.75
# Prop. variance: 0.25 Weight: 3.0
# Prop. variance: 0.25 Weight: 3.25
# Prop. variance: 0.25 Weight: 3.5
# Prop. variance: 0.25 Weight: 3.75
# Prop. variance: 0.3 Weight: 0.25
# Prop. variance: 0.3 Weight: 0.5
# Prop. variance: 0.3 Weight: 0.75
# Prop. variance: 0.3 Weight: 1.0
# Prop. variance: 0.3 Weight: 1.25
# Prop. variance: 0.3 Weight: 1.5
# Prop. variance: 0.3 Weight: 1.75
# Prop. variance: 0.3 Weight: 2.0
# Prop. variance: 0.3 Weight: 2.25
# Prop. variance: 0.3 Weight: 2.5
# Prop. variance: 0.3 Weight: 2.75
# Prop. variance: 0.3 Weight: 3.0
# Prop. variance: 0.3 Weight: 3.25
# Prop. variance: 0.3 Weight: 3.5
# Prop. variance: 0.3 Weight: 3.75
# Prop. variance: 0.35 Weight: 0.25
# Prop. variance: 0.35 Weight: 0.5
# Prop. variance: 0.35 Weight: 0.75
# Prop. variance: 0.35 Weight: 1.0
# Prop. variance: 0.35 Weight: 1.25
# Prop. variance: 0.35 Weight: 1.5
# Prop. variance: 0.35 Weight: 1.75
# Prop. variance: 0.35 Weight: 2.0
# Prop. variance: 0.35 Weight: 2.25
# Prop. variance: 0.35 Weight: 2.5
# Prop. variance: 0.35 Weight: 2.75
# Prop. variance: 0.35 Weight: 3.0
# Prop. variance: 0.35 Weight: 3.25
# Prop. variance: 0.35 Weight: 3.5
# Prop. variance: 0.35 Weight: 3.75
# Prop. variance: 0.4 Weight: 0.25
# Prop. variance: 0.4 Weight: 0.5
# Prop. variance: 0.4 Weight: 0.75
# Prop. variance: 0.4 Weight: 1.0
# Prop. variance: 0.4 Weight: 1.25
# Prop. variance: 0.4 Weight: 1.5
# Prop. variance: 0.4 Weight: 1.75
# Prop. variance: 0.4 Weight: 2.0
# Prop. variance: 0.4 Weight: 2.25
# Prop. variance: 0.4 Weight: 2.5
# Prop. variance: 0.4 Weight: 2.75
# Prop. variance: 0.4 Weight: 3.0
# Prop. variance: 0.4 Weight: 3.25
# Prop. variance: 0.4 Weight: 3.5
# Prop. variance: 0.4 Weight: 3.75
# Prop. variance: 0.45 Weight: 0.25
# Prop. variance: 0.45 Weight: 0.5
# Prop. variance: 0.45 Weight: 0.75
# Prop. variance: 0.45 Weight: 1.0
# Prop. variance: 0.45 Weight: 1.25
# Prop. variance: 0.45 Weight: 1.5
# Prop. variance: 0.45 Weight: 1.75
# Prop. variance: 0.45 Weight: 2.0
# Prop. variance: 0.45 Weight: 2.25
# Prop. variance: 0.45 Weight: 2.5
# Prop. variance: 0.45 Weight: 2.75
# Prop. variance: 0.45 Weight: 3.0
# Prop. variance: 0.45 Weight: 3.25
# Prop. variance: 0.45 Weight: 3.5
# Prop. variance: 0.45 Weight: 3.75
# Prop. variance: 0.5 Weight: 0.25
# Prop. variance: 0.5 Weight: 0.5
# Prop. variance: 0.5 Weight: 0.75
# Prop. variance: 0.5 Weight: 1.0
# Prop. variance: 0.5 Weight: 1.25
# Prop. variance: 0.5 Weight: 1.5
# Prop. variance: 0.5 Weight: 1.75
# Prop. variance: 0.5 Weight: 2.0
# Prop. variance: 0.5 Weight: 2.25
# Prop. variance: 0.5 Weight: 2.5
# Prop. variance: 0.5 Weight: 2.75
# Prop. variance: 0.5 Weight: 3.0
# Prop. variance: 0.5 Weight: 3.25
# Prop. variance: 0.5 Weight: 3.5
# Prop. variance: 0.5 Weight: 3.75
# Prop. variance: 0.55 Weight: 0.25
# Prop. variance: 0.55 Weight: 0.5
# Prop. variance: 0.55 Weight: 0.75
# Prop. variance: 0.55 Weight: 1.0
# Prop. variance: 0.55 Weight: 1.25
# Prop. variance: 0.55 Weight: 1.5
# Prop. variance: 0.55 Weight: 1.75
# Prop. variance: 0.55 Weight: 2.0
# Prop. variance: 0.55 Weight: 2.25
# Prop. variance: 0.55 Weight: 2.5
# Prop. variance: 0.55 Weight: 2.75
# Prop. variance: 0.55 Weight: 3.0
# Prop. variance: 0.55 Weight: 3.25
# Prop. variance: 0.55 Weight: 3.5
# Prop. variance: 0.55 Weight: 3.75
# Prop. variance: 0.6 Weight: 0.25
# Prop. variance: 0.6 Weight: 0.5
# Prop. variance: 0.6 Weight: 0.75
# Prop. variance: 0.6 Weight: 1.0
# Prop. variance: 0.6 Weight: 1.25
# Prop. variance: 0.6 Weight: 1.5
# Prop. variance: 0.6 Weight: 1.75
# Prop. variance: 0.6 Weight: 2.0
# Prop. variance: 0.6 Weight: 2.25
# Prop. variance: 0.6 Weight: 2.5
# Prop. variance: 0.6 Weight: 2.75
# Prop. variance: 0.6 Weight: 3.0
# Prop. variance: 0.6 Weight: 3.25
# Prop. variance: 0.6 Weight: 3.5
# Prop. variance: 0.6 Weight: 3.75
# Prop. variance: 0.65 Weight: 0.25
# Prop. variance: 0.65 Weight: 0.5
# Prop. variance: 0.65 Weight: 0.75
# Prop. variance: 0.65 Weight: 1.0
# Prop. variance: 0.65 Weight: 1.25
# Prop. variance: 0.65 Weight: 1.5
# Prop. variance: 0.65 Weight: 1.75
# Prop. variance: 0.65 Weight: 2.0
# Prop. variance: 0.65 Weight: 2.25
# Prop. variance: 0.65 Weight: 2.5
# Prop. variance: 0.65 Weight: 2.75
# Prop. variance: 0.65 Weight: 3.0
# Prop. variance: 0.65 Weight: 3.25
# Prop. variance: 0.65 Weight: 3.5
# Prop. variance: 0.65 Weight: 3.75
# Prop. variance: 0.7 Weight: 0.25
# Prop. variance: 0.7 Weight: 0.5
# Prop. variance: 0.7 Weight: 0.75
# Prop. variance: 0.7 Weight: 1.0
# Prop. variance: 0.7 Weight: 1.25
# Prop. variance: 0.7 Weight: 1.5
# Prop. variance: 0.7 Weight: 1.75
# Prop. variance: 0.7 Weight: 2.0
# Prop. variance: 0.7 Weight: 2.25
# Prop. variance: 0.7 Weight: 2.5
# Prop. variance: 0.7 Weight: 2.75
# Prop. variance: 0.7 Weight: 3.0
# Prop. variance: 0.7 Weight: 3.25
# Prop. variance: 0.7 Weight: 3.5
# Prop. variance: 0.7 Weight: 3.75

# %%
cox_adjusted_pca_scores.drop_duplicates().pivot(index = "PCA",columns = "Weight", values = "score")
# Out:
# Weight      0.25      0.50      0.75      1.00      1.25      1.50      1.75  \
# PCA
# 0.05    0.574239  0.574239  0.574239  0.574239  0.574239  0.574239  0.574239
# 0.10    0.574239  0.574239  0.574239  0.574239  0.574239  0.574239  0.574239
# 0.15    0.576724  0.576729  0.576733  0.576733  0.576733  0.576733  0.576733
# 0.20    0.685623  0.685555  0.685515  0.685542  0.685551  0.685542  0.685533
# 0.25    0.692482  0.693285  0.693262  0.693258  0.693267  0.693271  0.693262
# 0.30    0.665716  0.666621  0.666640  0.666626  0.666622  0.666605  0.666605
# 0.35    0.686950  0.686879  0.686870  0.687704  0.687686  0.688548  0.688583
# 0.40    0.718406  0.718305  0.718230  0.718226  0.718225  0.718234  0.718261
# 0.45    0.680158  0.681081  0.681930  0.682778  0.682769  0.682746  0.682768
# 0.50    0.726418  0.727247  0.727203  0.727118  0.727105  0.727970  0.727939
# 0.55    0.702922  0.703544  0.705985  0.706688  0.707475  0.707487  0.707482
# 0.60    0.724922  0.726540  0.726477  0.727307  0.727157  0.727153  0.727118
# 0.65    0.711865  0.711587  0.711464  0.712296  0.712318  0.711385  0.711320
# 0.70    0.691213  0.690506  0.690224  0.689067  0.688861  0.688813  0.688807
#
# Weight      2.00      2.25      2.50      2.75      3.00      3.25      3.50  \
# PCA
# 0.05    0.574239  0.574239  0.574239  0.574239  0.574239  0.574239  0.574239
# 0.10    0.574239  0.574239  0.574239  0.574239  0.574239  0.574239  0.574239
# 0.15    0.576733  0.576733  0.576733  0.576733  0.576733  0.576733  0.576733
# 0.20    0.685533  0.685533  0.685533  0.685533  0.685533  0.685533  0.685533
# 0.25    0.693262  0.693262  0.693253  0.693244  0.693244  0.693252  0.693266
# 0.30    0.666609  0.666613  0.666613  0.666613  0.666613  0.666613  0.667488
# 0.35    0.688600  0.688595  0.688595  0.688587  0.688583  0.688583  0.688574
# 0.40    0.718261  0.718257  0.718261  0.718274  0.718283  0.718283  0.718278
# 0.45    0.682776  0.682772  0.682776  0.682768  0.682772  0.682768  0.682768
# 0.50    0.727926  0.727926  0.727925  0.727907  0.727899  0.727925  0.727929
# 0.55    0.707429  0.707425  0.707398  0.707385  0.707359  0.707315  0.707306
# 0.60    0.727100  0.727087  0.727064  0.727069  0.727090  0.727095  0.727069
# 0.65    0.712118  0.712082  0.712087  0.712104  0.711260  0.712156  0.713039
# 0.70    0.688679  0.688608  0.688546  0.688516  0.688498  0.688444  0.688378
#
# Weight      3.75
# PCA
# 0.05    0.574239
# 0.10    0.574239
# 0.15    0.576733
# 0.20    0.685533
# 0.25    0.693270
# 0.30    0.667488
# 0.35    0.688574
# 0.40    0.718278
# 0.45    0.682768
# 0.50    0.727925
# 0.55    0.707319
# 0.60    0.727056
# 0.65    0.713026
# 0.70    0.688384

# %%
cox_adjusted_pca_scores.sort_values("score")
# Out:
#       PCA  Weight     score
# 0    0.05    0.25  0.574239
# 29   0.10    3.75  0.574239
# 28   0.10    3.50  0.574239
# 27   0.10    3.25  0.574239
# 26   0.10    3.00  0.574239
# ..    ...     ...       ...
# 143  0.50    2.25  0.727926
# 142  0.50    2.00  0.727926
# 148  0.50    3.50  0.727929
# 141  0.50    1.75  0.727939
# 140  0.50    1.50  0.727970
#
# [210 rows x 3 columns]

# %% [markdown]
# 0.5 with weight 1.5 produces the best result

# %% [markdown]
# Fitting final model:

# %%
pca = PCA(n_components = 0.5)
X_tr_pca = pd.DataFrame(pca.fit_transform(X_tr))
X_tr_pca.index = X_tr.index

# %%
pickle.dump(cph, open('adjusted_cox_pca_wc.pkl', 'wb'))

# %%
# creating a case dataframe
cases_adjusted_df = X_tr_pca.join(y_tr).query("subcohort == False")

cases_adjusted_df = cases_adjusted_df.assign(
    # setting events outside subcohort to start just before they occur
    start_time = lambda df: df["duration"] - 0.001,
    # adding appropriate weight
    weight = 1,
    subcohort = False
)

# creating a subcohort dataframe
subcohort_adjusted_df = X_tr_pca.join(y_tr).query("subcohort == True")

subcohort_adjusted_df = subcohort_adjusted_df.assign(
        # if it is a case, the weight should be the same as the subcohort until close to the time of the event. 
        duration = lambda df: np.where(df["event"], df["duration"] - 0.001, df["duration"]), 
        # the events start from the origin
        start_time = 0, 
        event = False,
        weight = 1.5 ,
        subcohort = True
    )

case_subcohort_adjusted_df = pd.concat([cases_adjusted_df,subcohort_adjusted_df]).drop(columns = "subcohort")

cph = CoxPHFitter()
cph.fit(case_subcohort_adjusted_df, entry_col = "start_time", duration_col = "duration",event_col = "event",weights_col = "weight",robust = True)
# Out:
# <lifelines.CoxPHFitter: fitted with 1487.5 total observations, 892.5 right-censored observations>

# %%
pickle.dump(cph, open('adjusted_cox_wc.pkl', 'wb'))
